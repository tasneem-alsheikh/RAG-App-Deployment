# %%
import os
import requests
from bs4 import BeautifulSoup
import pickle
import numpy as np
from mistralai import Mistral
import time

# Set your API key (ensure it's kept secure)
os.environ["MISTRAL_API_KEY"] = "uPgaqejCGJ8ZU6Oe0uDmUQl1jzcFtUAv"
api_key = os.getenv("MISTRAL_API_KEY")

# Define policy URLs with descriptive names
policies = {
    "Student Conduct Policy": "https://www.udst.edu.qa/about-udst/institutional-excellence-ie/policies-and-procedures/student-conduct-policy",
    "Academic Schedule Policy": "https://www.udst.edu.qa/about-udst/institutional-excellence-ie/udst-policies-and-procedures/academic-schedule-policy",
    "Sport and Wellness Facilities Policy": "https://www.udst.edu.qa/about-udst/institutional-excellence-ie/policies-and-procedures/sport-and-wellness-facilities-and",
    "Graduate Admissions Policy": "https://www.udst.edu.qa/about-udst/institutional-excellence-ie/policies-and-procedures/graduate-admissions-policy",
    "Use Library Space Policy": "https://www.udst.edu.qa/about-udst/institutional-excellence-ie/policies-and-procedures/use-library-space-policy",
    "International Student Procedure": "https://www.udst.edu.qa/about-udst/institutional-excellence-ie/udst-policies-and-procedures/international-student-procedure",
    "Registration Procedure": "https://www.udst.edu.qa/about-udst/institutional-excellence-ie/udst-policies-and-procedures/registration-procedure",
    "Scholarship and Financial Assistance": "https://www.udst.edu.qa/about-udst/institutional-excellence-ie/policies-and-procedures/scholarship-and-financial-assistance",
    "Library Study Room Booking Procedure": "https://www.udst.edu.qa/about-udst/institutional-excellence-ie/policies-and-procedures/library-study-room-booking-procedure",
    "Graduate Final Grade Procedure": "https://www.udst.edu.qa/about-udst/institutional-excellence-ie/policies-and-procedures/graduate-final-grade-procedure"
}

def get_policy_text(url):
    """Scrape the policy text from the given URL."""
    response = requests.get(url)
    soup = BeautifulSoup(response.text, "html.parser")
    # Try to locate the main content. You may need to adjust this selector.
    content = soup.find("div", class_="policy-content")
    if content:
        return content.get_text(separator=" ", strip=True)
    else:
        # Fallback: get all text
        return soup.get_text(separator=" ", strip=True)

# Scrape all policies and store their text in a dictionary
policy_texts = {}
for policy_name, url in policies.items():
    print(f"Scraping {policy_name} from {url}...")
    policy_texts[policy_name] = get_policy_text(url)

# Chunk the texts into smaller pieces. Here, we use a fixed character length.
chunk_size = 512
chunks = []
for policy_name, text in policy_texts.items():
    if not text:
        continue
    for i in range(0, len(text), chunk_size):
        chunk_text = text[i:i+chunk_size]
        chunks.append({"policy": policy_name, "text": chunk_text})

print("Total chunks created:", len(chunks))

# Save the chunks to a pickle file
with open("udst_chunks.pkl", "wb") as f:
    pickle.dump(chunks, f)
print("Saved udst_chunks.pkl")

# Function to generate an embedding for a given text using Mistral
def get_text_embedding(text, client):
    response = client.embeddings.create(model="mistral-embed", inputs=[text])
    return np.array(response.data[0].embedding)

# Initialize the Mistral client once
client = Mistral(api_key=api_key)

# Generate embeddings for each chunk
embeddings_list = []
for i, chunk in enumerate(chunks):
    try:
        embedding = get_text_embedding(chunk["text"], client)
        embeddings_list.append(embedding)
        print(f"Processed chunk {i+1}/{len(chunks)}")
        time.sleep(2)  # Wait 2 seconds between requests to avoid rate limiting
    except Exception as e:
        print(f"Error processing chunk {i+1}: {e}")


# Convert embeddings list to a NumPy array
embeddings_array = np.array(embeddings_list)

# Save the embeddings to a pickle file
with open("udst_embeddings.pkl", "wb") as f:
    pickle.dump(embeddings_array, f)
print("Saved udst_embeddings.pkl")
# Out:
# Scraping Student Conduct Policy from https://www.udst.edu.qa/about-udst/institutional-excellence-ie/policies-and-procedures/student-conduct-policy...
# Scraping Academic Schedule Policy from https://www.udst.edu.qa/about-udst/institutional-excellence-ie/udst-policies-and-procedures/academic-schedule-policy...
# Scraping Sport and Wellness Facilities Policy from https://www.udst.edu.qa/about-udst/institutional-excellence-ie/policies-and-procedures/sport-and-wellness-facilities-and...
# Scraping Graduate Admissions Policy from https://www.udst.edu.qa/about-udst/institutional-excellence-ie/policies-and-procedures/graduate-admissions-policy...
# Scraping Use Library Space Policy from https://www.udst.edu.qa/about-udst/institutional-excellence-ie/policies-and-procedures/use-library-space-policy...
# Scraping International Student Procedure from https://www.udst.edu.qa/about-udst/institutional-excellence-ie/udst-policies-and-procedures/international-student-procedure...
# Scraping Registration Procedure from https://www.udst.edu.qa/about-udst/institutional-excellence-ie/udst-policies-and-procedures/registration-procedure...
# Scraping Scholarship and Financial Assistance from https://www.udst.edu.qa/about-udst/institutional-excellence-ie/policies-and-procedures/scholarship-and-financial-assistance...
# Scraping Library Study Room Booking Procedure from https://www.udst.edu.qa/about-udst/institutional-excellence-ie/policies-and-procedures/library-study-room-booking-procedure...
# Scraping Graduate Final Grade Procedure from https://www.udst.edu.qa/about-udst/institutional-excellence-ie/policies-and-procedures/graduate-final-grade-procedure...
# Total chunks created: 360
# Saved udst_chunks.pkl
# Processed chunk 1/360
# Processed chunk 2/360
# Processed chunk 3/360
# Processed chunk 4/360
# Processed chunk 5/360
# Processed chunk 6/360
# Processed chunk 7/360
# Processed chunk 8/360
# Processed chunk 9/360
# Processed chunk 10/360
# Processed chunk 11/360
# Processed chunk 12/360
# Processed chunk 13/360
# Processed chunk 14/360
# Processed chunk 15/360
# Processed chunk 16/360
# Processed chunk 17/360
# Processed chunk 18/360
# Processed chunk 19/360
# Processed chunk 20/360
# Processed chunk 21/360
# Processed chunk 22/360
# Processed chunk 23/360
# Processed chunk 24/360
# Processed chunk 25/360
# Processed chunk 26/360
# Processed chunk 27/360
# Processed chunk 28/360
# Processed chunk 29/360
# Processed chunk 30/360
# Processed chunk 31/360
# Processed chunk 32/360
# Processed chunk 33/360
# Processed chunk 34/360
# Processed chunk 35/360
# Processed chunk 36/360
# Processed chunk 37/360
# Processed chunk 38/360
# Processed chunk 39/360
# Processed chunk 40/360
# Processed chunk 41/360
# Processed chunk 42/360
# Processed chunk 43/360
# Processed chunk 44/360
# Processed chunk 45/360
# Processed chunk 46/360
# Processed chunk 47/360
# Processed chunk 48/360
# Processed chunk 49/360
# Processed chunk 50/360
# Processed chunk 51/360
# Processed chunk 52/360
# Processed chunk 53/360
# Processed chunk 54/360
# Processed chunk 55/360
# Processed chunk 56/360
# Processed chunk 57/360
# Processed chunk 58/360
# Processed chunk 59/360
# Processed chunk 60/360
# Processed chunk 61/360
# Processed chunk 62/360
# Processed chunk 63/360
# Processed chunk 64/360
# Processed chunk 65/360
# Processed chunk 66/360
# Processed chunk 67/360
# Processed chunk 68/360
# Processed chunk 69/360
# Processed chunk 70/360
# Processed chunk 71/360
# Processed chunk 72/360
# Processed chunk 73/360
# Processed chunk 74/360
# Processed chunk 75/360
# Processed chunk 76/360
# Processed chunk 77/360
# Processed chunk 78/360
# Processed chunk 79/360
# Processed chunk 80/360
# Processed chunk 81/360
# Processed chunk 82/360
# Processed chunk 83/360
# Processed chunk 84/360
# Processed chunk 85/360
# Processed chunk 86/360
# Processed chunk 87/360
# Processed chunk 88/360
# Processed chunk 89/360
# Processed chunk 90/360
# Processed chunk 91/360
# Processed chunk 92/360
# Processed chunk 93/360
# Processed chunk 94/360
# Processed chunk 95/360
# Processed chunk 96/360
# Processed chunk 97/360
# Processed chunk 98/360
# Processed chunk 99/360
# Processed chunk 100/360
# Processed chunk 101/360
# Processed chunk 102/360
# Processed chunk 103/360
# Processed chunk 104/360
# Processed chunk 105/360
# Processed chunk 106/360
# Processed chunk 107/360
# Processed chunk 108/360
# Processed chunk 109/360
# Processed chunk 110/360
# Processed chunk 111/360
# Processed chunk 112/360
# Processed chunk 113/360
# Processed chunk 114/360
# Processed chunk 115/360
# Processed chunk 116/360
# Processed chunk 117/360
# Processed chunk 118/360
# Processed chunk 119/360
# Processed chunk 120/360
# Processed chunk 121/360
# Processed chunk 122/360
# Processed chunk 123/360
# Processed chunk 124/360
# Processed chunk 125/360
# Processed chunk 126/360
# Processed chunk 127/360
# Processed chunk 128/360
# Processed chunk 129/360
# Processed chunk 130/360
# Processed chunk 131/360
# Processed chunk 132/360
# Processed chunk 133/360
# Processed chunk 134/360
# Processed chunk 135/360
# Processed chunk 136/360
# Processed chunk 137/360
# Processed chunk 138/360
# Processed chunk 139/360
# Processed chunk 140/360
# Processed chunk 141/360
# Processed chunk 142/360
# Processed chunk 143/360
# Processed chunk 144/360
# Processed chunk 145/360
# Processed chunk 146/360
# Processed chunk 147/360
# Processed chunk 148/360
# Processed chunk 149/360
# Processed chunk 150/360
# Processed chunk 151/360
# Processed chunk 152/360
# Processed chunk 153/360
# Processed chunk 154/360
# Processed chunk 155/360
# Processed chunk 156/360
# Processed chunk 157/360
# Processed chunk 158/360
# Processed chunk 159/360
# Processed chunk 160/360
# Processed chunk 161/360
# Processed chunk 162/360
# Processed chunk 163/360
# Processed chunk 164/360
# Processed chunk 165/360
# Processed chunk 166/360
# Processed chunk 167/360
# Processed chunk 168/360
# Processed chunk 169/360
# Processed chunk 170/360
# Processed chunk 171/360
# Processed chunk 172/360
# Processed chunk 173/360
# Processed chunk 174/360
# Processed chunk 175/360
# Processed chunk 176/360
# Processed chunk 177/360
# Processed chunk 178/360
# Processed chunk 179/360
# Processed chunk 180/360
# Processed chunk 181/360
# Processed chunk 182/360
# Processed chunk 183/360
# Processed chunk 184/360
# Processed chunk 185/360
# Processed chunk 186/360
# Processed chunk 187/360
# Processed chunk 188/360
# Processed chunk 189/360
# Processed chunk 190/360
# Processed chunk 191/360
# Processed chunk 192/360
# Processed chunk 193/360
# Processed chunk 194/360
# Processed chunk 195/360
# Processed chunk 196/360
# Processed chunk 197/360
# Processed chunk 198/360
# Processed chunk 199/360
# Processed chunk 200/360
# Processed chunk 201/360
# Processed chunk 202/360
# Processed chunk 203/360
# Processed chunk 204/360
# Processed chunk 205/360
# Processed chunk 206/360
# Processed chunk 207/360
# Processed chunk 208/360
# Processed chunk 209/360
# Processed chunk 210/360
# Processed chunk 211/360
# Processed chunk 212/360
# Processed chunk 213/360
# Processed chunk 214/360
# Processed chunk 215/360
# Processed chunk 216/360
# Processed chunk 217/360
# Processed chunk 218/360
# Processed chunk 219/360
# Processed chunk 220/360
# Processed chunk 221/360
# Processed chunk 222/360
# Processed chunk 223/360
# Processed chunk 224/360
# Processed chunk 225/360
# Processed chunk 226/360
# Processed chunk 227/360
# Processed chunk 228/360
# Processed chunk 229/360
# Processed chunk 230/360
# Processed chunk 231/360
# Processed chunk 232/360
# Processed chunk 233/360
# Processed chunk 234/360
# Processed chunk 235/360
# Processed chunk 236/360
# Processed chunk 237/360
# Processed chunk 238/360
# Processed chunk 239/360
# Processed chunk 240/360
# Processed chunk 241/360
# Processed chunk 242/360
# Processed chunk 243/360
# Processed chunk 244/360
# Processed chunk 245/360
# Processed chunk 246/360
# Processed chunk 247/360
# Processed chunk 248/360
# Processed chunk 249/360
# Processed chunk 250/360
# Processed chunk 251/360
# Processed chunk 252/360
# Processed chunk 253/360
# Processed chunk 254/360
# Processed chunk 255/360
# Processed chunk 256/360
# Processed chunk 257/360
# Processed chunk 258/360
# Processed chunk 259/360
# Processed chunk 260/360
# Processed chunk 261/360
# Processed chunk 262/360
# Processed chunk 263/360
# Processed chunk 264/360
# Processed chunk 265/360
# Processed chunk 266/360
# Processed chunk 267/360
# Processed chunk 268/360
# Processed chunk 269/360
# Processed chunk 270/360
# Processed chunk 271/360
# Processed chunk 272/360
# Processed chunk 273/360
# Processed chunk 274/360
# Processed chunk 275/360
# Processed chunk 276/360
# Processed chunk 277/360
# Processed chunk 278/360
# Processed chunk 279/360
# Processed chunk 280/360
# Processed chunk 281/360
# Processed chunk 282/360
# Processed chunk 283/360
# Processed chunk 284/360
# Processed chunk 285/360
# Processed chunk 286/360
# Processed chunk 287/360
# Processed chunk 288/360
# Processed chunk 289/360
# Processed chunk 290/360
# Processed chunk 291/360
# Processed chunk 292/360
# Processed chunk 293/360
# Processed chunk 294/360
# Processed chunk 295/360
# Processed chunk 296/360
# Processed chunk 297/360
# Processed chunk 298/360
# Processed chunk 299/360
# Processed chunk 300/360
# Processed chunk 301/360
# Processed chunk 302/360
# Processed chunk 303/360
# Processed chunk 304/360
# Processed chunk 305/360
# Processed chunk 306/360
# Processed chunk 307/360
# Processed chunk 308/360
# Processed chunk 309/360
# Processed chunk 310/360
# Processed chunk 311/360
# Processed chunk 312/360
# Processed chunk 313/360
# Processed chunk 314/360
# Processed chunk 315/360
# Processed chunk 316/360
# Processed chunk 317/360
# Processed chunk 318/360
# Processed chunk 319/360
# Processed chunk 320/360
# Processed chunk 321/360
# Processed chunk 322/360
# Processed chunk 323/360
# Processed chunk 324/360
# Processed chunk 325/360
# Processed chunk 326/360
# Processed chunk 327/360
# Processed chunk 328/360
# Processed chunk 329/360
# Processed chunk 330/360
# Processed chunk 331/360
# Processed chunk 332/360
# Processed chunk 333/360
# Processed chunk 334/360
# Processed chunk 335/360
# Processed chunk 336/360
# Processed chunk 337/360
# Processed chunk 338/360
# Processed chunk 339/360
# Processed chunk 340/360
# Processed chunk 341/360
# Processed chunk 342/360
# Processed chunk 343/360
# Processed chunk 344/360
# Processed chunk 345/360
# Processed chunk 346/360
# Processed chunk 347/360
# Processed chunk 348/360
# Processed chunk 349/360
# Processed chunk 350/360
# Processed chunk 351/360
# Processed chunk 352/360
# Processed chunk 353/360
# Processed chunk 354/360
# Processed chunk 355/360
# Processed chunk 356/360
# Processed chunk 357/360
# Processed chunk 358/360
# Processed chunk 359/360
# Processed chunk 360/360
# Saved udst_embeddings.pkl
